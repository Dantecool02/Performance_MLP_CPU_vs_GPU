# %% [markdown]
# ### Optimizations to make:
#
# - Make use of torch
# - Run the torch optimized code on GPUs (Still not decided which GPU)
# - If we can use torch.compile() somehow, in combination with above
# - Can we use lower precision on the float values, bfloat16?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
import random

# %%
# Adjust file reading if we are on google colab

def is_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

if is_colab():
    from google.colab import drive
    drive.mount('/content/drive')
    train_path = '/content/drive/MyDrive/DD2358_Data/train.csv'
    test_path = '/content/drive/MyDrive/DD2358_Data/test.csv'
else:
    train_path = '../data/train.csv'
    test_path = '../data/test.csv'


# Seeds
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cpu

# %% [markdown]
# ### Import data

# %%
# Read files
train_df = pd.read_csv(train_path, header = None)
test_df = pd.read_csv(test_path, header = None)



# Check data sizes and class balances
print("Number of samples in train file: " + str(train_df.shape[0]))
print("Number of samples in test file: " + str(test_df.shape[0]))

# Check Class balance in train and test
print("\nNumber of class 0 in train file: " + str(train_df[0].eq(0).sum()) + f", {float(train_df[0].eq(0).sum()/train_df.shape[0]):.2f}% of train set")
print("Number of class 1 in train file: " + str(train_df[0].eq(1).sum()) + f", {float(train_df[0].eq(1).sum()/train_df.shape[0]):.2f}% of train set")
print("Number of class 2 in train file: " + str(train_df[0].eq(2).sum()) + f", {float(train_df[0].eq(2).sum()/train_df.shape[0]):.2f}% of train set")

print("\nNumber of class 0 in test file: " + str(test_df[0].eq(0).sum()) + f", {float(test_df[0].eq(0).sum()/test_df.shape[0]):.2f}% of test set")
print("Number of class 1 in test file: " + str(test_df[0].eq(1).sum()) + f", {float(test_df[0].eq(1).sum()/test_df.shape[0]):.2f}% of test set")
print("Number of class 0 in test file: " + str(test_df[0].eq(2).sum()) + f", {float(test_df[0].eq(2).sum()/test_df.shape[0]):.2f}% of test set")
# Out:
# Number of samples in train file: 2700
# Number of samples in test file: 675
#
# Number of class 0 in train file: 900, 0.33% of train set
# Number of class 1 in train file: 900, 0.33% of train set
# Number of class 2 in train file: 900, 0.33% of train set
#
# Number of class 0 in test file: 225, 0.33% of test set
# Number of class 1 in test file: 225, 0.33% of test set
# Number of class 0 in test file: 225, 0.33% of test set

# %% [markdown]
# ### Datasets are perfectly balanced, lets split it into X and Y and normalise the data

# %%
# Train data
train_X = train_df.iloc[:, 1:].values.astype(np.float32)
train_Y = train_df.iloc[:, 0].values

# Test data
test_X = test_df.iloc[:, 1:].values.astype(np.float32)
test_Y = test_df.iloc[:, 0].values

# Normalise the X values to [0,1]
train_X /= np.float32(255)
test_X /= np.float32(255)

# Convert to tensors
train_X = torch.tensor(train_X)
train_Y = torch.tensor(train_Y)
test_X = torch.tensor(test_X)
test_Y = torch.tensor(test_Y)

sample_image = train_X[200,:].reshape(32,32)
plt.imshow(sample_image, cmap='gray', vmin=0, vmax=1)
plt.title("Sample 32x32 Grayscale Image")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Model parameters and constructing dataloader

# %%
# Dataloader
batch_size = train_X.shape[0]
print(batch_size)

train_dataset = TensorDataset(train_X, train_Y)
test_dataset  = TensorDataset(test_X, test_Y)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Model parameters
input_dim = train_X.shape[1]  # 1024 pixels
hidden_dim1 = 8
#hidden_dim2 = 64
output_dim = 3  # 3 classes
# Out:
# 2700

# %% [markdown]
# ### Construct the Model with nn Module

# %%
# Key note: ReLU was way better than Sigmoid by default in torch, this is because 
# Weights initilization is Kaiming uniform, and not Xavi which is needed for Sigmoid

# Great model is lr = 0.001, decrease of factor 0.8 with patience = 10 on linear lr_scheduler

class MLP (nn.Module):
    def __init__(self, input_dim, hidden_dim1, output_dim):
        super(MLP, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim1, bias=True),
            #nn.BatchNorm1d(hidden_dim1),
            nn.Sigmoid(),
            #nn.Dropout(0.1),
            nn.Linear(hidden_dim1, output_dim, bias=True),
        )
    
    def forward(self, x):
        return self.net(x)

def init_weights(m):
    if isinstance(m, nn.Linear):
        # Initialize weights uniformly in the range [-0.2, 0.2]
        nn.init.uniform_(m.weight, -0.2, 0.2)
        # Optionally, initialize biases to zero
        if m.bias is not None:
            nn.init.zeros_(m.bias)

model = MLP(input_dim, hidden_dim1, output_dim).to(device)
model.apply(init_weights)

print(model)

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=1)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.8, patience=10)
# Out:
# MLP(
#   (net): Sequential(
#     (0): Linear(in_features=1024, out_features=8, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=8, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ### Lets train it

# %%
num_epochs = 600
patience = 100  # if no improvement for x epochs, stop training
best_val_loss = float('inf')
epochs_without_improve = 0
train_losses = []
val_losses = []
val_accuracies = []
best_model_state = None

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs)  # raw logits
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
    
    train_loss = running_loss / len(train_dataset)
    train_losses.append(train_loss)
    
    # Evaluate on validation (test) set
    model.eval()
    running_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (preds == labels).sum().item()
    
    val_loss = running_val_loss / len(test_dataset)
    val_acc = 100.0 * correct / total
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)
    
    scheduler.step(val_loss)
    
    print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}%")
    
    # Early stopping check
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state = model.state_dict()
        epochs_without_improve = 0
    else:
        epochs_without_improve += 1
        if epochs_without_improve >= patience:
            print("Early stopping triggered.")
            break
        

# =============================================================================
# Plot Training and Validation Curves
# =============================================================================

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curves")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(val_accuracies, label="Validation Accuracy", color="green")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Validation Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# =============================================================================
# Final Evaluation on Test Set
# =============================================================================

if best_model_state is not None:
    model.load_state_dict(best_model_state)

model.eval()
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (preds == labels).sum().item()
final_acc = 100.0 * correct / total
print("Final Test Accuracy: {:.2f}%".format(final_acc))

hidden_layer = model.net[0]
hidden_layer_weights = hidden_layer.weight[0]
print(hidden_layer_weights)
# Out:
# Epoch 1/600 | Train Loss: 1.1078 | Val Loss: 1.1041 | Val Acc: 33.33%
# Epoch 2/600 | Train Loss: 1.1039 | Val Loss: 1.1015 | Val Acc: 33.33%
# Epoch 3/600 | Train Loss: 1.1013 | Val Loss: 1.0997 | Val Acc: 33.33%
# Epoch 4/600 | Train Loss: 1.0996 | Val Loss: 1.0992 | Val Acc: 33.48%
# Epoch 5/600 | Train Loss: 1.0992 | Val Loss: 1.0996 | Val Acc: 33.33%
# Epoch 6/600 | Train Loss: 1.0996 | Val Loss: 1.0994 | Val Acc: 33.33%
# Epoch 7/600 | Train Loss: 1.0994 | Val Loss: 1.0988 | Val Acc: 33.48%
# Epoch 8/600 | Train Loss: 1.0989 | Val Loss: 1.0983 | Val Acc: 33.78%
# Epoch 9/600 | Train Loss: 1.0984 | Val Loss: 1.0981 | Val Acc: 38.07%
# Epoch 10/600 | Train Loss: 1.0982 | Val Loss: 1.0982 | Val Acc: 29.19%
# Epoch 11/600 | Train Loss: 1.0982 | Val Loss: 1.0983 | Val Acc: 31.56%
# Epoch 12/600 | Train Loss: 1.0983 | Val Loss: 1.0984 | Val Acc: 32.00%
# Epoch 13/600 | Train Loss: 1.0983 | Val Loss: 1.0983 | Val Acc: 32.15%
# Epoch 14/600 | Train Loss: 1.0983 | Val Loss: 1.0981 | Val Acc: 31.41%
# Epoch 15/600 | Train Loss: 1.0981 | Val Loss: 1.0979 | Val Acc: 29.33%
# Epoch 16/600 | Train Loss: 1.0978 | Val Loss: 1.0976 | Val Acc: 36.15%
# Epoch 17/600 | Train Loss: 1.0976 | Val Loss: 1.0975 | Val Acc: 37.33%
# Epoch 18/600 | Train Loss: 1.0974 | Val Loss: 1.0975 | Val Acc: 34.37%
# Epoch 19/600 | Train Loss: 1.0973 | Val Loss: 1.0975 | Val Acc: 34.22%
# Epoch 20/600 | Train Loss: 1.0972 | Val Loss: 1.0974 | Val Acc: 34.22%
# Epoch 21/600 | Train Loss: 1.0971 | Val Loss: 1.0972 | Val Acc: 35.56%
# Epoch 22/600 | Train Loss: 1.0970 | Val Loss: 1.0971 | Val Acc: 38.67%
# Epoch 23/600 | Train Loss: 1.0968 | Val Loss: 1.0969 | Val Acc: 40.00%
# Epoch 24/600 | Train Loss: 1.0967 | Val Loss: 1.0968 | Val Acc: 35.41%
# Epoch 25/600 | Train Loss: 1.0966 | Val Loss: 1.0967 | Val Acc: 32.15%
# Epoch 26/600 | Train Loss: 1.0965 | Val Loss: 1.0966 | Val Acc: 33.48%
# Epoch 27/600 | Train Loss: 1.0963 | Val Loss: 1.0964 | Val Acc: 38.37%
# Epoch 28/600 | Train Loss: 1.0961 | Val Loss: 1.0963 | Val Acc: 41.48%
# Epoch 29/600 | Train Loss: 1.0960 | Val Loss: 1.0961 | Val Acc: 40.59%
# Epoch 30/600 | Train Loss: 1.0958 | Val Loss: 1.0960 | Val Acc: 40.59%
# Epoch 31/600 | Train Loss: 1.0957 | Val Loss: 1.0959 | Val Acc: 40.89%
# Epoch 32/600 | Train Loss: 1.0955 | Val Loss: 1.0957 | Val Acc: 41.63%
# Epoch 33/600 | Train Loss: 1.0954 | Val Loss: 1.0956 | Val Acc: 41.63%
# Epoch 34/600 | Train Loss: 1.0952 | Val Loss: 1.0955 | Val Acc: 39.11%
# Epoch 35/600 | Train Loss: 1.0951 | Val Loss: 1.0954 | Val Acc: 37.19%
# Epoch 36/600 | Train Loss: 1.0949 | Val Loss: 1.0952 | Val Acc: 36.74%
# Epoch 37/600 | Train Loss: 1.0948 | Val Loss: 1.0951 | Val Acc: 39.56%
# Epoch 38/600 | Train Loss: 1.0946 | Val Loss: 1.0949 | Val Acc: 42.07%
# Epoch 39/600 | Train Loss: 1.0944 | Val Loss: 1.0948 | Val Acc: 43.41%
# Epoch 40/600 | Train Loss: 1.0942 | Val Loss: 1.0946 | Val Acc: 43.41%
# Epoch 41/600 | Train Loss: 1.0941 | Val Loss: 1.0945 | Val Acc: 43.11%
# Epoch 42/600 | Train Loss: 1.0939 | Val Loss: 1.0943 | Val Acc: 38.07%
# Epoch 43/600 | Train Loss: 1.0937 | Val Loss: 1.0942 | Val Acc: 34.22%
# Epoch 44/600 | Train Loss: 1.0936 | Val Loss: 1.0941 | Val Acc: 34.07%
# Epoch 45/600 | Train Loss: 1.0935 | Val Loss: 1.0940 | Val Acc: 37.19%
# Epoch 46/600 | Train Loss: 1.0934 | Val Loss: 1.0938 | Val Acc: 43.11%
# Epoch 47/600 | Train Loss: 1.0932 | Val Loss: 1.0937 | Val Acc: 46.96%
# Epoch 48/600 | Train Loss: 1.0930 | Val Loss: 1.0936 | Val Acc: 49.93%
# Epoch 49/600 | Train Loss: 1.0928 | Val Loss: 1.0934 | Val Acc: 46.96%
# Epoch 50/600 | Train Loss: 1.0926 | Val Loss: 1.0932 | Val Acc: 43.11%
# Epoch 51/600 | Train Loss: 1.0924 | Val Loss: 1.0931 | Val Acc: 38.81%
# Epoch 52/600 | Train Loss: 1.0923 | Val Loss: 1.0930 | Val Acc: 38.52%
# Epoch 53/600 | Train Loss: 1.0921 | Val Loss: 1.0928 | Val Acc: 42.07%
# Epoch 54/600 | Train Loss: 1.0919 | Val Loss: 1.0926 | Val Acc: 47.85%
# Epoch 55/600 | Train Loss: 1.0917 | Val Loss: 1.0924 | Val Acc: 51.26%
# Epoch 56/600 | Train Loss: 1.0915 | Val Loss: 1.0922 | Val Acc: 49.63%
# Epoch 57/600 | Train Loss: 1.0912 | Val Loss: 1.0920 | Val Acc: 45.19%
# Epoch 58/600 | Train Loss: 1.0910 | Val Loss: 1.0918 | Val Acc: 38.81%
# Epoch 59/600 | Train Loss: 1.0908 | Val Loss: 1.0916 | Val Acc: 38.22%
# Epoch 60/600 | Train Loss: 1.0905 | Val Loss: 1.0914 | Val Acc: 44.30%
# Epoch 61/600 | Train Loss: 1.0902 | Val Loss: 1.0911 | Val Acc: 50.22%
# Epoch 62/600 | Train Loss: 1.0900 | Val Loss: 1.0909 | Val Acc: 51.11%
# Epoch 63/600 | Train Loss: 1.0897 | Val Loss: 1.0907 | Val Acc: 47.70%
# Epoch 64/600 | Train Loss: 1.0894 | Val Loss: 1.0905 | Val Acc: 43.56%
# Epoch 65/600 | Train Loss: 1.0891 | Val Loss: 1.0902 | Val Acc: 42.67%
# Epoch 66/600 | Train Loss: 1.0888 | Val Loss: 1.0899 | Val Acc: 46.81%
# Epoch 67/600 | Train Loss: 1.0885 | Val Loss: 1.0897 | Val Acc: 50.67%
# Epoch 68/600 | Train Loss: 1.0882 | Val Loss: 1.0894 | Val Acc: 50.52%
# Epoch 69/600 | Train Loss: 1.0879 | Val Loss: 1.0891 | Val Acc: 47.70%
# Epoch 70/600 | Train Loss: 1.0875 | Val Loss: 1.0888 | Val Acc: 44.44%
# Epoch 71/600 | Train Loss: 1.0872 | Val Loss: 1.0885 | Val Acc: 47.26%
# Epoch 72/600 | Train Loss: 1.0868 | Val Loss: 1.0882 | Val Acc: 50.07%
# Epoch 582/600 | Train Loss: 0.8102 | Val Loss: 0.8147 | Val Acc: 72.89%
# Epoch 583/600 | Train Loss: 0.8099 | Val Loss: 0.8148 | Val Acc: 72.15%
# Epoch 584/600 | Train Loss: 0.8097 | Val Loss: 0.8142 | Val Acc: 73.04%
# Epoch 585/600 | Train Loss: 0.8094 | Val Loss: 0.8144 | Val Acc: 72.00%
# Epoch 586/600 | Train Loss: 0.8091 | Val Loss: 0.8137 | Val Acc: 73.04%
# Epoch 587/600 | Train Loss: 0.8089 | Val Loss: 0.8140 | Val Acc: 72.00%
# Epoch 588/600 | Train Loss: 0.8086 | Val Loss: 0.8132 | Val Acc: 73.33%
# Epoch 589/600 | Train Loss: 0.8083 | Val Loss: 0.8135 | Val Acc: 72.00%
# Epoch 590/600 | Train Loss: 0.8079 | Val Loss: 0.8127 | Val Acc: 73.04%
# Epoch 591/600 | Train Loss: 0.8076 | Val Loss: 0.8127 | Val Acc: 72.30%
# Epoch 592/600 | Train Loss: 0.8072 | Val Loss: 0.8122 | Val Acc: 72.44%
# Epoch 593/600 | Train Loss: 0.8068 | Val Loss: 0.8120 | Val Acc: 72.30%
# Epoch 594/600 | Train Loss: 0.8065 | Val Loss: 0.8119 | Val Acc: 72.59%
# Epoch 595/600 | Train Loss: 0.8063 | Val Loss: 0.8114 | Val Acc: 72.59%
# Epoch 596/600 | Train Loss: 0.8060 | Val Loss: 0.8115 | Val Acc: 72.44%
# Epoch 597/600 | Train Loss: 0.8058 | Val Loss: 0.8109 | Val Acc: 72.59%
# Epoch 598/600 | Train Loss: 0.8055 | Val Loss: 0.8110 | Val Acc: 72.74%
# Epoch 599/600 | Train Loss: 0.8052 | Val Loss: 0.8105 | Val Acc: 72.44%
# Epoch 600/600 | Train Loss: 0.8048 | Val Loss: 0.8104 | Val Acc: 72.44%
# Final Test Accuracy: 72.44%
# tensor([0.0890, 0.0534, 0.0326,  ..., 0.2005, 0.1114, 0.1895],
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# ### General Notes from testing:
#
# Double hidden layer with more neurons in first than second improvs the models accuracy potential. Using Relu, dropout(0.3) and layersizes = [input_dim, 128, 64, output_dim] worked well with this. Good generelization. Really seems to be aproblem in need of two hidden layers
#
# However, Dropout is only relevant if we have large enough network, otherwise the model becomes way too simple and cant learn properly
#
# For Double layer architecure the nn.BatchNordm1d(any_hidden_layer_dim) after the nn.linear and before activation function is absolutely fundamental. Without - > 46% final accuracy, with it for both the linear from input to hidden1 and from hidden1 to hidden2 we get 86% accuracy. Absolutely fundamental.
#
# Significant improvement for this dataset with ReLu in comparisson to Sigmoid, 70 -> 86% validation accuracy
#
# Suspect that the training and test data have bad seed and overall arent a good split, as training probably dont represent test good enough
#
# Lower learning rate = More stable improvement, but does converge earlier with a little worse accuracy
#
#
#
# TODO:
#
# To pass assignment:
# - Fix the loss and optimizer to somehow incorporate the customized loss and optimizer in the original code. The problem is getting that to run with torch
#
# For fun:
# - Understand BatchNorm1d
# - Dropout effect on different layer sizes
# - Should the layer sizes in a MLP only decrease layer by layer (Not risk the problem of simply copying from layer to another, there was fix for this problem though somehow (See sparse autoencdoers))
